# %% [markdown]
# # Validating VGG16 Model

# %%
import tensorflow as tf
from keras.models import load_model
model1 = load_model('C:\\Users\\User\\Desktop\\Clg stuffs\\vggmodelfinal (1).h5')

# %%
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 227, 227, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 227, 227, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 113, 113, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 113, 113, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 113, 113, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np 
from matplotlib import pyplot as plt
img1 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\crack1.jpg',target_size=(227,227))
plt.imshow(img1)
img1 = image.img_to_array(img1)
img1 = img1/255.0
img1 = np.expand_dims(img1,axis=0)
pred1 = np.argmax(model1.predict(img1),axis=1)
if pred1[0] == 0:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\plaina4.png',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.9988176 0.0011824]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\glasscracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.1371427e-12 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\glasscrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.183056e-10 1.000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\cementcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[2.0595972e-13 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\roadcrack2.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.2751381e-04 9.9987245e-01]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\buildingcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.2440546e-08 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\roadcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.326743e-04 9.998673e-01]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\dought.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.00200891 0.9979911 ]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\seapcrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[5.4698535e-10 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\crack3.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[4.3126092e-05 9.9995685e-01]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\doorcrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.00190709 0.99809295]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\holecrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.10853616e-04 9.99889135e-01]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\pinkwall.png',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.96713704 0.03286303]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\bluewall.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.98519355 0.01480643]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\bricls.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.1873659e-12 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\homewalls.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[3.263158e-11 1.000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00001.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model1.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0.998906   0.00109399]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00002.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 1.4379686e-38]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00003.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1. 0.]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00015.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 1.5565678e-35]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00025.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.000000e+00 8.201257e-35]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00030.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1. 0.]]
# This image doesn't contain Crack!!!

# %% [markdown]
# # Validating Mobile net

# %%
import tensorflow as tf
from keras.models import load_model
model2 = load_model('C:\\Users\\User\\Desktop\\Clg stuffs\\mobilenetv2modelfinal (1).h5')

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 114, 114, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 114, 114, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 114, 114, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 114, 114, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 114, 114, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np 
from matplotlib import pyplot as plt
img1 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\crack1.jpg',target_size=(227,227))
plt.imshow(img1)
img1 = image.img_to_array(img1)
img1 = img1/255.0
img1 = np.expand_dims(img1,axis=0)
pred1 = np.argmax(model2.predict(img1),axis=1)
if pred1[0] == 0:
    print("This image doesn't contain Crack!!!")
else:
    print("This image contains Crack!!!")
# Out:
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\plaina4.png',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 1.3862266e-27]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\glasscracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\glasscrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\cementcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\roadcrack2.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\buildingcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\roadcracks.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\dought.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[2.0820948e-32 1.0000000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\seapcrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\crack3.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[5.06211e-24 1.00000e+00]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\doorcrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\holecrack.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\bluewall.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.000000e+00 3.918744e-17]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\pinkwall.png',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 3.5374203e-14]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00001.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.000000e+00 2.008287e-35]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\homewalls.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[0. 1.]]
# This image contains Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00002.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 1.4379686e-38]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00001.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.000000e+00 2.008287e-35]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00030.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1. 0.]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00015.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.0000000e+00 1.5565678e-35]]
# This image doesn't contain Crack!!!

# %%
img12 =image.load_img('C:\\Users\\User\\Desktop\\Clg stuffs\\00025.jpg',target_size=(227,227))
plt.imshow(img12)
img12 = image.img_to_array(img12)
img12 = img12/255.0
img12 = np.expand_dims(img12,axis=0)
pred1 = model2.predict(img12)
print(pred1)
pred1 = np.argmax(pred1,axis=1)



if pred1[0] == 1:
    print("This image contains Crack!!!")
else:
    print("This image doesn't contain Crack!!!")
# Out:
# [[1.000000e+00 8.201257e-35]]
# This image doesn't contain Crack!!!
